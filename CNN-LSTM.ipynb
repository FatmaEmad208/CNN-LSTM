# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, TimeDistributed, Conv2D, MaxPooling2D, UpSampling2D, Flatten, LSTM, Dense, RepeatVector, Reshape

# %% [markdown]
# # **Data Preprocessing**

# %%
n_frames = 10               # Number of frames per video sequence
height, width = 64, 64      # Frame dimensions
channels = 3                # RGB channels

# %%
def load_video_frames(video_path, n_frames=10, frame_size=(64, 64)):

    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    # Select n evenly spaced frame indices
    frame_indices = np.linspace(0, total_frames - 1, n_frames).astype(int)
    frames = []
    for idx in frame_indices:
        cap.set(cv2.CAP_PROP_POS_FRAMES, idx)
        ret, frame = cap.read()
        if ret:
            frame = cv2.resize(frame, frame_size)
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(frame)
    cap.release()
    # If not enough frames are read, repeat the last frame
    while len(frames) < n_frames:
        frames.append(frames[-1])
    frames = np.array(frames, dtype=np.float32) / 255.0  # Normalize to [0, 1]
    return frames

# %%
def load_dataset(dataset_dir, n_frames=10, frame_size=(64, 64)):

    video_sequences = []
    for filename in os.listdir(dataset_dir):
        if filename.endswith('.mp4') or filename.endswith('.avi'):
            video_path = os.path.join(dataset_dir, filename)
            frames = load_video_frames(video_path, n_frames, frame_size)
            video_sequences.append(frames)
    video_sequences = np.array(video_sequences)
    # Final shape: (num_videos, n_frames, height, width, channels)
    return video_sequences

# %%
dataset_dir = '/content/drive/My Drive/dataset/Avenue_Dataset/Avenue_Dataset/training_videos'
video_sequences = load_dataset(dataset_dir, n_frames, (height, width))
print("Dataset shape:", video_sequences.shape)
# Out:
# Dataset shape: (16, 10, 64, 64, 3)

# %% [markdown]
# # **CNN-LSTM Autoencoder Model**

# %%
def build_autoencoder(n_frames, height, width, channels):
    input_frames = Input(shape=(n_frames, height, width, channels))

    # CNN Encoder: Process each frame individually
    x = TimeDistributed(Conv2D(32, (3, 3), activation='relu', padding='same'))(input_frames)
    x = TimeDistributed(MaxPooling2D((2, 2), padding='same'))(x)
    x = TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same'))(x)
    x = TimeDistributed(MaxPooling2D((2, 2), padding='same'))(x)

    # Save shape for later use in the decoder
    shape_before_flatten = tf.keras.backend.int_shape(x)

    # Flatten the CNN output for each frame
    x = TimeDistributed(Flatten())(x)

    # LSTM Encoder: Capture temporal dependencies
    encoded = LSTM(128, activation='relu', return_sequences=False)(x)

    # Repeat the encoded vector to match the number of frames
    repeated = RepeatVector(n_frames)(encoded)

    # LSTM Decoder: Reconstruct the sequence of features
    x = LSTM(128, activation='relu', return_sequences=True)(repeated)

    # Recover the flattened CNN feature dimensions
    flattened_dim = shape_before_flatten[2] * shape_before_flatten[3] * shape_before_flatten[4]
    x = TimeDistributed(Dense(flattened_dim, activation='relu'))(x)

    # Reshape back to the CNN feature map dimensions
    x = TimeDistributed(Reshape((shape_before_flatten[2], shape_before_flatten[3], shape_before_flatten[4])))(x)

    # CNN Decoder: Reconstruct the original frames
    x = TimeDistributed(UpSampling2D((2, 2)))(x)
    x = TimeDistributed(Conv2D(64, (3, 3), activation='relu', padding='same'))(x)
    x = TimeDistributed(UpSampling2D((2, 2)))(x)
    decoded_frames = TimeDistributed(Conv2D(channels, (3, 3), activation='sigmoid', padding='same'))(x)

    autoencoder = Model(inputs=input_frames, outputs=decoded_frames)
    autoencoder.compile(optimizer='adam', loss='mse')
    autoencoder.summary()
    return autoencoder

autoencoder = build_autoencoder(n_frames, height, width, channels)
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 10, 64, 64, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_55                  │ (None, 10, 64, 64, 32)      │             896 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_56                  │ (None, 10, 32, 32, 32)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_57                  │ (None, 10, 32, 32, 64)      │          18,496 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_58                  │ (None, 10, 16, 16, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_59                  │ (None, 10, 16384)           │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_10 (LSTM)                       │ (None, 128)                 │       8,454,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ repeat_vector_5 (RepeatVector)       │ (None, 10, 128)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_11 (LSTM)                       │ (None, 10, 128)             │         131,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_60                  │ (None, 10, 16384)           │       2,113,536 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_61                  │ (None, 10, 16, 16, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_62                  │ (None, 10, 32, 32, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_63                  │ (None, 10, 32, 32, 64)      │          36,928 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_64                  │ (None, 10, 64, 64, 64)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_65                  │ (None, 10, 64, 64, 3)       │           1,731 │
# │ (TimeDistributed)                    │                             │                 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,757,827 (41.04 MB)
#  Trainable params: 10,757,827 (41.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # **Model Training**

# %%
history = autoencoder.fit(video_sequences, video_sequences,
                          epochs=100,
                          batch_size=4,
                          validation_split=0.1)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0045 - val_loss: 0.0086
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0045 - val_loss: 0.0089
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0042 - val_loss: 0.0087
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0042 - val_loss: 0.0087
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0043 - val_loss: 0.0086
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0042 - val_loss: 0.0087
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0041 - val_loss: 0.0084
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0038 - val_loss: 0.0086
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0038 - val_loss: 0.0088
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0040 - val_loss: 0.0083
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0038 - val_loss: 0.0085
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0041 - val_loss: 0.0084
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0037 - val_loss: 0.0083
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0035 - val_loss: 0.0086
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0037 - val_loss: 0.0085
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0036 - val_loss: 0.0083
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0036 - val_loss: 0.0084
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0034 - val_loss: 0.0085
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0034 - val_loss: 0.0084
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0034 - val_loss: 0.0084
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0035 - val_loss: 0.0083
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0032 - val_loss: 0.0082
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0035 - val_loss: 0.0085
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0034 - val_loss: 0.0084
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0033 - val_loss: 0.0083
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0034 - val_loss: 0.0085
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0035 - val_loss: 0.0084
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0034 - val_loss: 0.0083
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0033 - val_loss: 0.0085
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0033 - val_loss: 0.0087
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0036 - val_loss: 0.0085
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0032 - val_loss: 0.0105
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0042 - val_loss: 0.0085
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0036 - val_loss: 0.0087
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0036 - val_loss: 0.0103
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0039 - val_loss: 0.0084
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0037 - val_loss: 0.0085
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0036 - val_loss: 0.0088
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0036 - val_loss: 0.0085
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0032 - val_loss: 0.0086
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0031 - val_loss: 0.0082
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029 - val_loss: 0.0083
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0030 - val_loss: 0.0084
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0031 - val_loss: 0.0084
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0028 - val_loss: 0.0084
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0030 - val_loss: 0.0087
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0028 - val_loss: 0.0084
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0029 - val_loss: 0.0088
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0030 - val_loss: 0.0085
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0028 - val_loss: 0.0084
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0028 - val_loss: 0.0086
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0034 - val_loss: 0.0087
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0030 - val_loss: 0.0085
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0030 - val_loss: 0.0083
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029 - val_loss: 0.0084
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0028 - val_loss: 0.0086
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0028 - val_loss: 0.0083
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0027 - val_loss: 0.0087
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0026 - val_loss: 0.0083
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0026 - val_loss: 0.0084
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0026 - val_loss: 0.0086
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0027 - val_loss: 0.0083
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0026 - val_loss: 0.0083
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0026 - val_loss: 0.0087
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0028 - val_loss: 0.0083
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0025 - val_loss: 0.0083
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0026 - val_loss: 0.0085
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0025 - val_loss: 0.0086
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0026 - val_loss: 0.0085
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0024 - val_loss: 0.0083
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0023 - val_loss: 0.0085

# %% [markdown]
# # **Anomaly Detection**

# %%
test_video = load_video_frames('/content/drive/My Drive/dataset/Avenue_Dataset/Avenue_Dataset/testing_videos/01.avi', n_frames, (height, width))
test_video = np.expand_dims(test_video, axis=0)  # add batch dimension

reconstructed_video = autoencoder.predict(test_video)
reconstruction_error = np.mean((test_video - reconstructed_video) ** 2)
print("Reconstruction error:", reconstruction_error)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Reconstruction error: 0.012100729

# %% [markdown]
# ## **Visualizing Training progress**

# %%
import plotly.graph_objects as go

# Plotting the Loss Curve

fig = go.Figure()
fig.add_trace(go.Scatter(y=history.history['loss'],
                         mode='lines+markers',
                         name='Train Loss'))
fig.add_trace(go.Scatter(y=history.history['val_loss'],
                         mode='lines+markers',
                         name='Validation Loss'))
fig.update_layout(title="Model Loss Over Epochs",
                  xaxis_title="Epoch",
                  yaxis_title="Loss")
fig.show()

# Plot the reconstruction error for each frame
fig = go.Figure()
fig.add_trace(go.Scatter(
    y=frame_errors,
    mode='lines+markers',
    name='Reconstruction Error'
))
fig.update_layout(
    title="Reconstruction Error per Frame",
    xaxis_title="Frame Index",
    yaxis_title="Mean Squared Error"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4b97b6a-04b0-4256-87f2-a35c6961f94d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4b97b6a-04b0-4256-87f2-a35c6961f94d")) {                    Plotly.newPlot(                        "b4b97b6a-04b0-4256-87f2-a35c6961f94d",                        [{"mode":"lines+markers","name":"Train Loss","y":[0.004519973881542683,0.004457368515431881,0.004315519239753485,0.004195373971015215,0.004198369104415178,0.004048639442771673,0.004093765746802092,0.004027233459055424,0.004045926034450531,0.003965830896049738,0.003881830722093582,0.00391631992533803,0.0037757980171591043,0.003712364239618182,0.0036664046347141266,0.003650416387245059,0.003621041541919